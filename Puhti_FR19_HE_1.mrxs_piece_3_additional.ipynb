# %%
import PIL
from PIL import Image
import os, sys
import numpy as np
from PIL import Image, ImageDraw

Image.MAX_IMAGE_PIXELS

img = Image.open('/scratch/project_2000667/mapcad/turku_images_to_test/FR19/Histological_images/FR19_HE_1.mrxs_piece_3_additional.tif')


print(img.size)

print(img.format, img.size, img.mode)

# Importing ImageDraw for
# using floodfill function
from PIL import Image, ImageDraw

  
# Location of seed
seed = (0, 0)
  
# Pixel Value which would
# be used for replacement
rep_value = (255, 255, 255, 255)
  
# Calling the floodfill() function and
# passing it image, seed, value and
# thresh as arguments
ImageDraw.floodfill(img, seed, rep_value, thresh = 100)
  

with Image.open('/scratch/project_2000667/mapcad/turku_images_to_test/FR19/Histological_images/FR19_HE_1.mrxs_piece_3_additional.tif') as image:
    width, height = image.size
def main():
    try:
        #Relative Path
        img = Image.open('/scratch/project_2000667/mapcad/turku_images_to_test/FR19/Histological_images/FR19_HE_1.mrxs_piece_3_additional.tif')
        width, height = img.size
          
        area = (0, 0, width/3.5, height/1)
        img = img.crop(area)/scratch/project_2000667/mapcad/turku_images_to_test/FR19/Histological_images/FR19_HE_1.mrxs_piece_3_additional.tif
          
        #Saved in the thesis relative location
        img.save('/scratch/project_2000667/mapcad/turku_images_to_test/FR19/Histological_images/curated_FR19_HE_1.mrxs_piece_3_additional.tif') 
          
    except IOError:
        pass
  
if __name__ == "__main__":
    main()


def main():
    try:
        #Relative Path
        img = Image.open('/scratch/project_2000667/mapcad/turku_images_to_test/FR19/Histological_images/curated_FR19_HE_1.mrxs_piece_3_additional.tif') 
          
        #Angle given
        img = img.rotate(180) 
          
         #Saved in the same relative location
        img.save('/scratch/project_2000667/mapcad/turku_images_to_test/FR19/Histological_images/rotated_curated_FR19_HE_1.mrxs_piece_3_additional.tif')
    except IOError:
        pass
  
if __name__ == "__main__":
    main()

# Location of seed
seed = (0, 0)
  
# Pixel Value which would
# be used for replacement
rep_value = (255, 255, 255, 255)
  
# Calling the floodfill() function and
# passing it image, seed, value and
# thresh as arguments
ImageDraw.floodfill(img, seed, rep_value, thresh = 100)
  

with Image.open('/scratch/project_2000667/mapcad/turku_images_to_test/FR19/Histological_images/rotated_curated_FR19_HE_1.mrxs_piece_3_additional.tif') as image:
    width, height = image.size
def main():
    try:
        #Relative Path
        img = Image.open('/scratch/project_2000667/mapcad/turku_images_to_test/FR19/Histological_images/rotated_curated_FR19_HE_1.mrxs_piece_3_additional.tif')
        width, height = img.size
          
        area = (0, 0, width/1.909, height/1)
        img = img.crop(area)
          
        #Saved in the same relative location
        img.save('/scratch/project_2000667/mapcad/turku_images_to_test/FR19/Histological_images/curated_rotated_curated_FR19_HE_1.mrxs_piece_3_additional.tif') 
          
    except IOError:
        pass
  
if __name__ == "__main__":
    main()
def main():
    try:
        #Relative Path
        img = Image.open('/scratch/project_2000667/mapcad/turku_images_to_test/FR19/Histological_images/curated_rotated_curated_FR19_HE_1.mrxs_piece_3_additional.tif') 
          
        #Angle given
        img = img.rotate(180) 
          
         #Saved in the same relative location
        img.save('/scratch/project_2000667/mapcad/turku_images_to_test/FR19/Histological_images/curated_images/curated_FR19_HE_1.mrxs_piece_3_additional.tif')
    except IOError:
        pass
  
if __name__ == "__main__":
    main()
